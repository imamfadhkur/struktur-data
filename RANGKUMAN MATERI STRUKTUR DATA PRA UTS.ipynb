# %%
Rangkuman Materi Struktur Data Pra UTS
1. searching
    a. linear search
    b. binary search
2. hashing
    a. open addresing
        a) linear probbiing
        b) quadratic probbing
    b. close addressing(chaining)
3. sorting
    a. buble sort
    b. selection sort
    c. insertion sort
    d. quick sort
    e. merge sort
    f. shell sort

# %%
1. searching 
    a. linear search
        Linear search adalah metode untuk menemukan nilai target dalam daftar
    secara berurutan, memeriksa setiap elemen dari daftar untuk nilai target sampai kecocokan ditemukan atau
    sampai semua elemen telah dicari.
    Jika algoritma mencapai akhir daftar, pencarian berakhir dan nilai yang dicari tidak ditemukan.

# %%
#dibawah ini adalah contoh linear search dari belakang
search = 3
mylist = [1,2,3,4,5,6]
position = len(mylist) - 1
last = 0
found = False
while position >= last and not found:  #looping dari indeks terakhir menuju ke awal
  if mylist[position] == search:
    found = True
  else:
    position = position - 1

print("angka yang dicari",search)
if found:
  print('ditemukan pada index ke',position)
else:
  print("angka tidak ditemukan")

# %%
#dibawah ini adalah contoh linear search dari depan
search = 4
mylist = [1,2,3,4,5,6]
position = 0
last = len(mylist)
found = False
while position <= last and not found:     #looping dari indeks awal menuju ke akhir
  if mylist[position] == search:
    found = True
  else:
    position = position + 1

print("angka yang dicari",search)
if found:
  print('ditemukan pada index ke',position)
else:
  print("angka tidak ditemukan")
# Out:
# found the search number
# index 3

# %%
#dibawah ini adalah contoh linear search dengan function
def search(x,mylist):
  position = 0
  last = len(mylist)-1
  found = False
  while position <= last and not found:
    if mylist[position] == x:
      found = True
    else:
      position = position + 1
  if found:
    print(x,"angka ditemukan, berada pada index",position)
  else:
    print("angka tidak ditemukan")
mylist = [1,2,3,4,5,6]
print('mylist =',mylist)
x =int(input("Masukkan angka yg ingin dicari = "))
search(x,mylist)

# %%
    b. binary search
        metode binary search hanya digunakan untuk pencarian data pada array yang sudah terurut. proses yang terjadi pada
    pencarian dengan metode ini adalah sebagai berikut:
        1. membaca data array.
        2. apabila array belum terurut, diurutkan terlebih dahulu.
        3. menentukan data yang akan dicari.
        4. menentukan element tengah dari array.
        5. jika nilai element tengah sama dengan data yang dicari, maka proses pencarian selesai.
        6. jika nilai elemen tengah tidak sama dengan data yang dicari, maka:
            1. jika nilai elemen tengah lebih besar daripada data yang dicari,
               maka pencarian dilakukan pada setengah array pertama.
            2. jika nilai elemen tengah lebih kecil daripada data yang dicari,
               maka pencarian dilakukan pada setengah array berikutnya.

# %%
# #dibawah ini adalah contoh binary search, dengan midle sebagai patokan untuk pembanding nilai yanng dicari
print("\nbinary search 0")
search = 8
mylist = [4,2,1,23,5,3,4,56,3,5,4,67,56,53,3,45,8,6,7,77,12]
print("mylist = [4,2,1,23,5,3,4,56,3,5,4,67,56,53,3,45,8,6,7,77,12]")
mylist.sort()
print("diurutkan menjadi")
print(mylist)
position = 0
first = 0
last = len(mylist)-1
iterasi = 1
found = False
while first <= last and not found:
  mid = (first + last)//2
  if mylist[mid] == search:
    found = True
  else:
    if search < mylist[mid]:
      last = mid
    else:
      first = mid
  iterasi = iterasi + 1
print('angka yang dicari',search)
if found:
  print("angka yang dicari ditemukan pada index ke", mid)
  print("iterasi =",iterasi)
else:
  print("angka tidak ditemukan")
  print("iterasi =",iterasi)

# %%
2. hashing
    hashing adalah proses pengindeksan dan pengambilan elemen dalam struktur data untuk memberikan cara yang lebih cepat
dalam menemukan elemen menggunakan kunci hash. kunci hash ditentukan dengan cara data/nilai di modulus banyaknya kolom list. 
searching dalam hashing menggunakan hash key yang telah ditentukan.
di dalam hashing ada sebuah masalah yang dinamakan collision.
collision adalah ketika ada 2 item atau lebih memiliki slot yang sama, kita harus memiliki metode sistematis untuk
menempatkan item kedua atau selanjutnya di dalam tabel hash. Ada dua cara yaitu open addressing (linear dan quadratic)
dan close addressing (chaining probbing)
a. open addressing
    a) linear probbing
           Linear Probbing yaitu metode penempatan dengan cara melihat secara berurutan, slot demi slot,
        sampai menemukan sebuah posisi terbuka atau kosong. Jika ditemukan subuah posisi kosong maka item yang memiliki
        hash key yang sama ditaruh dalam posisi kosong tersebut. searching dalam linear probbing menggunakan cara linear.

# %%
# data yang dimasukkan = 54,26,93,17,77,31,44,55,20

table = [None] * 11

def hash(x):
  return x % 11

def insert(table,key,value):
  index = hash(key)
  if table[index] == None:
    table[index] = value
  else:
    collusion=index
    found = False
    ind=collusion+1
    if ind>= len(table)-1:
      ind = 0
    while (ind<=len(table)-1) and not(found):
      if table[ind]== None:
        found=True
        table[ind]=value
      ind=ind+1

print(table)
insert(table,54,54)
print(table)
insert(table,26,26)
print(table)
insert(table,93,93)
print(table)
insert(table,17,17)
print(table)
insert(table,77,77)
print(table)
insert(table,31,31)
print(table)
insert(table,44,44)
print(table)
insert(table,55,55)
print(table)
insert(table,20,20)
print(table)
insert(table,25,25)
print(table)

# %%
    b) quadratic probbing
            Quadratic probing adalah skema pengalamatan terbuka dalam pemrograman komputer untuk menyelesaikan collision
        dalam tabel hash, ketika nilai hash data yang masuk menunjukkan itu harus disimpan dalam slot atau
        bucket yang sudah diduduki. Quadratic probing beroperasi dengan mengambil indeks hash asli dan menambahkan nilai
        berturut-turut dari polinomial kuadratik sewenang-wenang sampai slot terbuka ditemukan.
        kuadrat probing yaitu metode penempatan yang berarti bahwa jika nilai hash pertama adalah h,
        nilai berturut-turut adalah h + 1, h + 4, h + 9, h + 16. begitu seterusnya.

# %%
table = [None] * 10
def hash(x):
  return x % 10


def insert(table,key,value):
  index = hash(key)
  if table[index] == None:
    table[index] = value
  else:
    collusion=index
    found = False
    i=1
    ind = collusion+1

    if ind > len(table)-1:
        ind = 0

    while (ind<=len(table)-1) and not(found):
      if table[ind]== None:
        found=True
        table[ind]=value
        ind = (collusion+(i*i)) % 11
      i=i+1

print(table)
insert(table,54,54)
print(table)
insert(table,26,26)
print(table)
insert(table,93,'93')
print(table)
insert(table,17,'17')
print(table)
insert(table,77,'77')
print(table)
insert(table,31,'31')
print(table)
insert(table,44,'44')
print(table)
insert(table,55,'55')
print(table)
# Out:
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, 54, None, None, None, None, None]
# [None, None, None, None, 54, None, 26, None, None, None]
# [None, None, None, '93', 54, None, 26, None, None, None]
# [None, None, None, '93', 54, None, 26, '17', None, None]
# [None, None, None, '93', 54, None, 26, '17', '77', None]
# [None, '31', None, '93', 54, None, 26, '17', '77', None]
# [None, '31', None, '93', 54, '44', 26, '17', '77', None]

# %%
    b. close addressing(Chaining)
        Chaining adalah metode yang memungkinkan banyak item terdapat pada lokasi yang sama di tabel hash.
    Ketika collision terjadi, item tersebut masih ditempatkan di slot yang tepat dari tabel hash. Seperti cotoh data dibawah ini
    [[77, 44, 55], [], [], [], [26], [93], [17], [], [], [31, 20], [54]]

# %%
# a. Chaining probbing
loop = 'y'
while (loop == 'y'):
  print('-------Chaining probbing-------')
  tabel = [[]for i in range(10)]
  print("data = 1,5,7,9,12,20,23,24,40,44,48")
  def hash(key):
    return key % 11
  def hashing(tabel,key,value):
    tabel[hash(key)].append(value)
  def search(tabel,x):
    index = hash(x)
    found = False
    ind = 0
    while ind <= (len(tabel[index])-1) and not found:
        if tabel[index][ind] == x:
            found = True
        else:
            ind += 1
    if found == True:
        print('data yang anda cari',tabel[index][ind])
        print('\ndata',x,'ditemukan pada indeks ke [%d][%d] pada table hash' %(index,ind))
    else:
        hashing(tabel,x,x)
        print('data',x,'tidak ditemukan')
  hashing(tabel,1,1)
  hashing(tabel,5,5)
  hashing(tabel,7,7)
  hashing(tabel,9,9)
  hashing(tabel,12,12)
  hashing(tabel,20,20)
  hashing(tabel,23,23)
  hashing(tabel,24,24)
  hashing(tabel,40,40)
  hashing(tabel,44,44)
  hashing(tabel,48,48)
  print('data tersebut diatas di proses dalam hashing(chaining probbing) menjadi-->')
  print(tabel)
  a=int(input("masukkan angka yang ingin dicari = "))
  search(tabel,a)
  loop = input("apakah ingin mengulangi lagi? (y/t)")

print ("""
      --- CREATED BY ---
Nama : Imam Fadhkur Rokhim
NIM  : 180411100001
Prodi: Teknik Informatika """)
# sorce code diatas adalah searcing data dalam tabel hash,
# dimana collision ditempatkan dalam tabel hash menggunakan chaining probbing

# %%
3. Sorting
    a. bubble sort
        Algoritma Bubble Sort ini merupakan proses pengurutan yang secara berangsur-angsur berpindah 
    ke posisi yang tepat karena itulah dinamakan Bubble yang artinya gelembung. Algoritma ini akan mengurutkan
    data dari yang terbesar ke yang terkecil (ascending) atau sebaliknya (descending).
    Secara sederhana, bisa didefenisikan algoritma Bubble Sort adalah pengurutan dengan cara pertukaran data dengan
    data disebelahnya secara terus menerus sampai dalam satu iterasi tertentu tidak ada lagi perubahan.

# %%
print('--- bubble sort ---')
lst = [5,0,1,10,7,2,5,4,6,9]
print(lst)
iterasi = 1
for k in range(1,len(lst)):
    for i in range(0,len(lst)-1):
        if lst[i]>lst[i+1]:
            lst[i],lst[i+1] = lst[i+1],lst[i]
        iterasi += 1
print('\ndiurutkan menjadi-->\n')
print(lst)

print('iterasi =',iterasi)

# %%
    b. Selection Sort
            Selection Sort adalah salah satu algoritma pengurutan data dari kecil ke besar (ascending) atau
        dari besar ke kecil (descending) dengan cara mencatat data yang terkecil/terbesar. Setelah data tecatat,
        data tersebut dipindahkan ke paling kanan/paling kiri.
        Selection Sort merupakan perkembangan dari Bubble Sort, akan tetapi lebih efisien, karena jika data pada Selection Sort
        sudah terurut maka perulangan akan berhenti. Sedangkan dengan Bubble Sort, perulangan akan berhenti
        sampai jumlah data pada list.
        
        ilustrasinya:
        8 5 7 1 9 3      # (1) menjadi nilai terkecil yang akan dipindahkan 
        1 5 7 8 9 3      # (3) menjadi nilai terkecil yang akan dipindahkan
        1 3 7 8 9 5      # (5) menjadi nilai terkecil yang akan dipindahkan
        1 3 5 8 9 7      # (7) menjadi nilai terkecil yang akan dipindahkan
        1 3 5 7 9 8      # (8) menjadi nilai terkecil yang akan dipindahkan
        1 3 5 7 8 9      # (9) menjadi nilai terkecil yang akan dipindahkan

# %%
print('--- selection sort ---')
lst = [5,0,1,10,7,2,5,4,6,9]
print(lst)
iterasi = 1
for i in range(0,len(lst)-1):
    min=i
    for j in range(i+1,len(lst)):
        if lst[j]<lst[min]:
            min = j
        iterasi += 1
    lst[i],lst[min]=lst[min],lst[i]
print('\ndiurutkan menjadi -->\n')
print(lst)
print('iterasi =',iterasi)

# %%
    c. insertion sort
        Prinsip dari algoritma selection sort adalah memilih elemen dengan nilai paling rendah dan menukar elemen tersebut
    dengan elemen ke-i. Nilai dari i dimulai dari 1 ke n, dimana n adalah jumlah total elemen dikurangi 1.

    Langkahnya seperti di bawah ini :
Pengecekan dimulai dari data ke-1 sampai dengan data ke n.
    1. Tentukan bilangan dengan index terkecil dari data bilangan tersebut.
    2. Tukar bilangan dengan index terkecil tersebut dengan bilangan pertama (i=1) dari data bilangan tersebut.
    3. Lakukan langkah 2 dan 3 untuk bilangan berikutnya (i=i+1) sampai di dapatkan data yang sesuai.

# %%
print('--- insertion Sort ---')
lst = [5,0,1,10,7,2,5,4,6,9]
print('\ndata =',lst)
iterasi = 1
for i in range(1,len(lst)):
    nilaiawal = lst[ i]
    hole = i
    while lst[hole-1] > nilaiawal and hole > 0   :
        lst[hole] = lst[hole-1]
        hole=hole-1
    iterasi += 1
    lst[hole] = nilaiawal
print('\ndata diurutkan menjadi -->\n')
print('data =',lst)
print('iterasi =',iterasi)

# %%
    d. Quick Sort
        Quick Sort adalah salah satu algoritma pengurutan data yang paling cepat, yaitu dengan membagi list
    menggunakan sebuah pivot. Quick Sort juga menggunakan rekursif dalam algoritmanya.
    Misalnya jika pengurutannya secara ascending, data yang kurang dari pivot sudah ditentukan ditaruh disebelah
    kirinya pivot sedangkan data yang lebih besar dari pivot maka ditaruh disebelah kanan pivot.
    Setelah dipisah, bagian-bagian yang sudah dipisah melakukan pembagian seperti sebelumnya karena ini sehingga
    Quick Sort menggunakan rekursif. Begitu seterusnya sampai data terurut.

# %%
print('--- Quick sort ---')
def QuickSortAwal(A):
    QuickSort(A,0,len(A)-1)

def QuickSort(A,start,end):
    if start<end:
        pIndex = Partition(A,start,end)
        QuickSort (A,start,pIndex-1)
        QuickSort (A,pIndex+1,end)

def Partition(A,start,end):
    pivot = A[end]
    pIndex = start
    for i in range(start,end):
        if (A[i] <= pivot):
            A[i],A[pIndex]=A[pIndex],A[i]
            pIndex=pIndex+1
    A[pIndex],A[end]=A[end],A[pIndex]
    return pIndex
A=[5,0,1,10,7,2,5,4,6,9]
print('\nbefore =',A)
QuickSortAwal(A)
print('\ndata diurutkan menjadi -->\n')
print('after =',A)

# %%
    e. Merge Sort
        Merge sort adalah algoritma Divide and Conquer. Ini membagi array input dalam dua bagian, memanggil dirinya untuk
    dua bagian tersebut dan kemudian menggabungkan dua bagian yang telah diurutkan. Merge() function
    digunakan untuk menggabungkan dua bagian.

# %%
print('--- merge sort ---')
def MergedSort(A):
    n = len(A)
    if (n<2):
       return
    mid = len(A)//2
    left = A[:mid]
    right = A[mid:]
    MergedSort(left)
    MergedSort(right)
    i=0
    j=0
    k=0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            A[k]=left[i]
            i=i+1
        else:
            A[k]=right[j]
            j=j+1
        k=k+1

    while i < len(left):
        A[k]=left[i]
        i=i+1
        k=k+1

    while j < len(right):
        A[k]=right[j]
        j=j+1
        k=k+1

Alist= [54,26,93,17,99,77,31,44,55,20,100]
print('\nbefore =',Alist)
MergedSort(Alist)
print('\ndiurutkan menjadi -->\n')
print('after =',Alist)

# %%
    f. sell sort
        Ini dapat dilihat sebagai generalisasi pengurutan berdasarkan pertukaran (bubble sort) atau pengurutan
    berdasarkan penyisipan (insertion sort). Metode ini dimulai dengan menyortir pasangan elemen yang berjauhan satu sama lain,
    kemudian secara progresif mengurangi kesenjangan antar elemen yang akan dibandingkan. Dimulai dengan elemen berjauhan,
    ia dapat memindahkan beberapa elemen out-of-place ke posisi lebih cepat dari pertukaran tetangga terdekat yang sederhana.

# %%
print('--- shell sort ---')
def shellSort(alist):
    sublistcount = len(alist)//2
    while sublistcount > 0:

      for startposition in range(sublistcount):
        gapInsertionSort(alist,startposition,sublistcount)
      sublistcount = sublistcount // 2

def gapInsertionSort(alist,start,gap):
    for i in range(start+gap,len(alist),gap):

        currentvalue = alist[i]
        position = i

        while position>=gap and alist[position-gap]>currentvalue:
            alist[position]=alist[position-gap]
            position = position-gap

        alist[position]=currentvalue


alist = [35,33,42,10,14,19,27,44]
print('\nbefore =',alist)
shellSort(alist)
print('\ndiurutkan menjadi -->\n')
print('after =',alist)
